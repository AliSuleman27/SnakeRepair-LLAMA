# %%
# Ahsan extracted bugs
import pandas as pd

# %%
df = pd.read_csv('datasets/repairllama_py.csv')

# %%
only_open_source = df[df['source'] == 'repairllama']

# %%
only_open_source.to_csv('codes_that_ahsan_gave_(repairllama).csv')

# %%
only_pyres = df[df['source'] == 'pyresbugs']

# %%
only_pyres.to_csv('only_pyres_ahsan.csv')

# %%
df1 = pd.read_csv('only_pyres_ahsan.csv')

# %%
df1['commit_sha'] = pd.Series("", index=df1.index, dtype="string")
df1['file_path'] = pd.Series("", index=df1.index, dtype="string")
df1.to_csv('only_pyres_ahsan.csv')

# %%
df.source.value_counts()
# Out:
# source
# competitive    70000
# pyresbugs       3661
# repairllama     3125
# Name: count, dtype: int64

# %%
rbr = df[df['source'] == 'competitive']
rbr['commit_sha'] = pd.Series("", index=rbr.index, dtype="string")
rbr['file_path'] = pd.Series("", index=rbr.index, dtype="string")
rbr.to_csv('only_rbr.csv')
# Out:
# /tmp/ipykernel_1864/1811196779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rbr['commit_sha'] = pd.Series("", index=rbr.index, dtype="string")
# /tmp/ipykernel_1864/1811196779.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rbr['file_path'] = pd.Series("", index=rbr.index, dtype="string")

# %%
df = pd.read_csv('/home/mrafi/codellms-fyp/SnakeRepair-LLAMA/finalized_datasets/actual_data/final_original_dataset.csv')
# Out:
# /tmp/ipykernel_1864/449510387.py:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/mrafi/codellms-fyp/SnakeRepair-LLAMA/finalized_datasets/actual_data/final_original_dataset.csv')

# %%
len(df)
# Out:
# 87541

# %%
df = df.drop_duplicates(subset=["buggy_code", "fixed_code"])

# %%
len(df)
# Out:
# 18770

# %%
lmk = pd.read_csv('/home/mrafi/codellms-fyp/SnakeRepair-LLAMA/finalized_datasets/actual_data/dataset_open_source_bugs.csv')

# %%
lmk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21159 entries, 0 to 21158
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21159 non-null  int64
#  1   repo            21159 non-null  object
#  2   file_path       21159 non-null  object
#  3   commit_sha      21159 non-null  object
#  4   commit_message  21159 non-null  object
#  5   buggy_code      21159 non-null  object
#  6   fixed_code      21159 non-null  object
#  7   type            21159 non-null  object
#  8   buggy_function  21159 non-null  object
#  9   fixed_function  21159 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.6+ MB

# %%
df_alisuleman = pd.read_csv('datasets/original_dataset_bugs.csv')
df_ahsan_muneeb = pd.read_csv('datasets/repairllama_py.csv')

# %%
df_alisuleman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27179 entries, 0 to 27178
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      27179 non-null  int64
#  1   repo            27179 non-null  object
#  2   file_path       27179 non-null  object
#  3   commit_sha      27179 non-null  object
#  4   commit_message  27179 non-null  object
#  5   buggy_code      27179 non-null  object
#  6   fixed_code      27179 non-null  object
#  7   type            27179 non-null  object
#  8   buggy_function  27179 non-null  object
#  9   fixed_function  27179 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %%
df_ahsan_muneeb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76786 entries, 0 to 76785
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   buggy_code             76786 non-null  object
#  1   fixed_code             76786 non-null  object
#  2   input_representation   76786 non-null  object
#  3   output_representation  76786 non-null  object
#  4   source                 76786 non-null  object
# dtypes: object(5)
# memory usage: 2.9+ MB

# %%
df1 = df_alisuleman.drop(columns=['file_path', 'commit_sha', 'commit_message','type','buggy_function','fixed_function', 'Unnamed: 0'])
df2 = df_ahsan_muneeb.drop(columns=['input_representation', 'output_representation'])

# %%
df1 = df1.rename(columns={'repo':'source'})

# %%
df1.columns, df2.columns
# Out:
# (Index(['source', 'buggy_code', 'fixed_code'], dtype='object'),
#  Index(['buggy_code', 'fixed_code', 'source'], dtype='object'))

# %%
df3 = pd.concat([df1,df2])

# %%
df3.__len__()
# Out:
# 103965

# %%
df3 = df3.drop_duplicates(subset=["buggy_code", "fixed_code"])

# %%
len(df3)
# Out:
# 99374

# %%
df3.to_csv('combined_dataset_99k_samples.csv',index=False)

# %%
import ast
import difflib
import logging
import sys
from typing import Dict, List, Optional, Tuple

import pandas as pd
from tqdm import tqdm

# Setup logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)


# ----------------------------------------------------------------------
# License stripping
# ----------------------------------------------------------------------
def strip_license(code: str) -> str:
    """
    Remove leading comment lines (starting with '#') and empty lines.
    Keeps everything after the first non‑comment, non‑empty line.
    """
    lines = code.splitlines()
    start = 0
    for i, line in enumerate(lines):
        stripped = line.strip()
        if stripped == "" or stripped.startswith("#"):
            continue
        else:
            start = i
            break
    else:
        # Entire file consisted of comments/empty lines? Return empty string.
        return ""
    return "\n".join(lines[start:])


# ----------------------------------------------------------------------
# Function extraction using AST
# ----------------------------------------------------------------------
class FunctionExtractor(ast.NodeVisitor):
    """
    Collects all top‑level functions and methods (not nested inside other functions).
    Stores them with a unique qualname: "class_name.method" for methods, "func_name" for top‑level.
    Also stores the source code segment and (start, end) line numbers.
    """

    def __init__(self, source: str):
        self.source = source
        self.context: List[str] = []          # stack of class names
        self.functions: Dict[str, Tuple[ast.FunctionDef, str, Tuple[int, int]]] = {}
        self._in_function = False              # whether we are inside a function (skip nested)

    def visit_ClassDef(self, node: ast.ClassDef) -> None:
        self.context.append(node.name)
        self.generic_visit(node)
        self.context.pop()

    def visit_FunctionDef(self, node: ast.FunctionDef) -> None:
        self._visit_function(node)

    def visit_AsyncFunctionDef(self, node: ast.AsyncFunctionDef) -> None:
        self._visit_function(node)

    def _visit_function(self, node: ast.FunctionDef) -> None:
        # Only record if not inside another function (i.e., at top‑level or inside a class)
        if not self._in_function:
            self._in_function = True
            qualname = ".".join(self.context + [node.name])
            # Get source segment
            func_source = ast.get_source_segment(self.source, node)
            if func_source is None:
                # Fallback: could reconstruct, but for safety we skip
                logger.warning(f"Could not extract source for function {qualname}")
            else:
                line_range = (node.lineno, node.end_lineno)
                self.functions[qualname] = (node, func_source, line_range)
            self.generic_visit(node)
            self._in_function = False
        else:
            # Nested function – skip
            self.generic_visit(node)


def extract_functions(source: str) -> Dict[str, Tuple[str, Tuple[int, int]]]:
    """
    Parse source and return a dictionary mapping qualname -> (source_code, (start_line, end_line)).
    Returns empty dict on syntax error.
    """
    try:
        tree = ast.parse(source)
    except SyntaxError as e:
        logger.error(f"Syntax error while parsing: {e}")
        return {}
    extractor = FunctionExtractor(source)
    extractor.visit(tree)
    return {name: (src, rng) for name, (_, src, rng) in extractor.functions.items()}


# ----------------------------------------------------------------------
# Global change detection using line diff
# ----------------------------------------------------------------------
def has_global_changes(
    buggy_lines: List[str],
    fixed_lines: List[str],
    buggy_func_ranges: Dict[str, Tuple[int, int]],
    fixed_func_ranges: Dict[str, Tuple[int, int]],
) -> bool:
    """
    Returns True if there are line differences that lie completely outside any function.
    """
    sm = difflib.SequenceMatcher(None, buggy_lines, fixed_lines)
    for tag, i1, i2, j1, j2 in sm.get_opcodes():
        if tag == "equal":
            continue
        # Changes in buggy version (deleted or replaced lines)
        if tag in ("delete", "replace"):
            for line_num in range(i1 + 1, i2 + 1):  # 1‑based
                if not any(start <= line_num <= end for start, end in buggy_func_ranges.values()):
                    return True
        # Changes in fixed version (inserted or replaced lines)
        if tag in ("insert", "replace"):
            for line_num in range(j1 + 1, j2 + 1):
                if not any(start <= line_num <= end for start, end in fixed_func_ranges.values()):
                    return True
    return False


# ----------------------------------------------------------------------
# Main processing script
# ----------------------------------------------------------------------
def main(input_csv: str, output_csv: str) -> None:
    logger.info(f"Reading {input_csv}")
    df = pd.read_csv(input_csv)

    # Drop columns if they exist
    drop_cols = ["input_representation", "output_representation"]
    existing_drop = [c for c in drop_cols if c in df.columns]
    if existing_drop:
        df = df.drop(columns=existing_drop)
        logger.info(f"Dropped columns: {existing_drop}")

    # Strip license from original buggy/fixed code and overwrite
    logger.info("Stripping license headers...")
    tqdm.pandas(desc="Stripping license")
    df["buggy_code"] = df["buggy_code"].progress_apply(
        lambda x: strip_license(x) if pd.notna(x) else x
    )
    df["fixed_code"] = df["fixed_code"].progress_apply(
        lambda x: strip_license(x) if pd.notna(x) else x
    )

    # Prepare new columns
    df["type"] = None
    df["buggy_function"] = None
    df["fixed_function"] = None

    # Keep track of rows to keep (only single‑function)
    keep_mask = [False] * len(df)

    # Process rows with tqdm
    logger.info("Classifying samples...")
    for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing"):
        buggy = row["buggy_code"]
        fixed = row["fixed_code"]

        if pd.isna(buggy) or pd.isna(fixed):
            logger.warning(f"Row {idx} has missing code, skipping")
            continue

        try:
            # Extract functions
            buggy_funcs = extract_functions(buggy)
            fixed_funcs = extract_functions(fixed)

            if not buggy_funcs or not fixed_funcs:
                print("parse error")
                continue

            buggy_sources = {name: src for name, (src, _) in buggy_funcs.items()}
            buggy_ranges = {name: rng for name, (_, rng) in buggy_funcs.items()}
            fixed_sources = {name: src for name, (src, _) in fixed_funcs.items()}
            fixed_ranges = {name: rng for name, (_, rng) in fixed_funcs.items()}

            # Identify changed, added, removed functions
            common_names = set(buggy_sources) & set(fixed_sources)
            changed = [name for name in common_names if buggy_sources[name] != fixed_sources[name]]
            added = set(fixed_sources) - set(buggy_sources)
            removed = set(buggy_sources) - set(fixed_sources)

            # Global changes outside functions
            buggy_lines = buggy.splitlines()
            fixed_lines = fixed.splitlines()
            global_change = has_global_changes(buggy_lines, fixed_lines, buggy_ranges, fixed_ranges)

            # Criteria for single‑function bug:
            #   exactly one changed function,
            #   no added functions,
            #   no removed functions,
            #   no global changes.
            if len(changed) == 1 and not added and not removed and not global_change:
                keep_mask[idx] = True
                key = changed[0]
                df.at[idx, "type"] = "single function"
                df.at[idx, "buggy_function"] = buggy_sources[key]
                df.at[idx, "fixed_function"] = fixed_sources[key]

        except Exception as e:
            logger.error(f"Row {idx} failed with exception: {e}")
            continue

    
    logger.info(f"Kept {len(df)} rows out of {len(df)}")

    # Save
    filtered_df.to_csv(output_csv, index=False)
    logger.info(f"Saved filtered dataset to {output_csv}")

# %%
main("combined_dataset_99k_samples.csv","filtered_first_pass_99k.csv")
# Out:
# 2026-02-18 04:27:21,227 - INFO - Reading combined_dataset_99k_samples.csv
# 2026-02-18 04:27:25,847 - INFO - Stripping license headers...
# Stripping license: 100%|██████████| 99374/99374 [00:00<00:00, 128470.61it/s]
# Stripping license: 100%|██████████| 99374/99374 [00:00<00:00, 128016.13it/s]
# 2026-02-18 04:27:27,415 - INFO - Classifying samples...
# Processing:   1%|          | 759/99374 [00:14<17:17, 95.09it/s]  2026-02-18 04:27:41,601 - ERROR - Syntax error while parsing: f-string: unmatched '(' (<unknown>, line 60)
# Processing:   1%|          | 770/99374 [00:14<21:55, 74.94it/s]
# parse error
# Processing:   4%|▍         | 3823/99374 [01:15<40:38, 39.18it/s]  2026-02-18 04:28:42,668 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 363)
# 2026-02-18 04:28:42,669 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 363)
# Processing:   4%|▍         | 3829/99374 [01:15<38:18, 41.57it/s]
# parse error
# Processing:   6%|▌         | 5742/99374 [02:05<33:52, 46.08it/s]  2026-02-18 04:29:32,705 - ERROR - Syntax error while parsing: f-string: unmatched '(' (<unknown>, line 101)
# Processing:   6%|▌         | 5757/99374 [02:05<28:39, 54.45it/s]
# parse error
# Processing:   8%|▊         | 7744/99374 [02:44<19:23, 78.76it/s]  2026-02-18 04:30:12,267 - ERROR - Syntax error while parsing: f-string expression part cannot include a backslash (<unknown>, line 109)
# Processing:   8%|▊         | 7761/99374 [02:45<23:25, 65.19it/s]
# parse error
# Processing:  11%|█         | 11055/99374 [04:43<51:31, 28.57it/s]  2026-02-18 04:32:10,798 - ERROR - Syntax error while parsing: f-string expression part cannot include a backslash (<unknown>, line 109)
# Processing:  11%|█         | 11065/99374 [04:43<42:23, 34.72it/s]
# parse error
# Processing:  16%|█▌        | 15939/99374 [11:35<1:29:39, 15.51it/s] 2026-02-18 04:39:03,235 - ERROR - Syntax error while parsing: f-string expression part cannot include a backslash (<unknown>, line 805)
# Processing:  16%|█▌        | 15957/99374 [11:35<35:37, 39.03it/s]
# parse error
# Processing:  19%|█▉        | 18720/99374 [14:05<49:28, 27.17it/s]  2026-02-18 04:41:32,822 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 216)
# 2026-02-18 04:41:32,823 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 221)
# 2026-02-18 04:41:32,829 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 216)
# 2026-02-18 04:41:32,830 - ERROR - Syntax error while parsing: expected '(' (<unknown>, line 216)
# 2026-02-18 04:41:32,873 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 26)
# 2026-02-18 04:41:32,874 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 26)
# Processing:  19%|█▉        | 18772/99374 [14:05<13:04, 102.78it/s]
# parse error
# parse error
# parse error
# Processing:  22%|██▏       | 21459/99374 [16:48<23:52, 54.40it/s]   2026-02-18 04:44:15,550 - ERROR - Syntax error while parsing: f-string: unmatched '[' (<unknown>, line 454)
# parse error
# Processing:  26%|██▋       | 26165/99374 [17:48<00:41, 1771.67it/s]2026-02-18 04:45:16,264 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 143)
# parse error
# Processing:  27%|██▋       | 26345/99374 [17:49<02:03, 590.21it/s] 2026-02-18 04:45:17,078 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 147 (<unknown>, line 149)
# 2026-02-18 04:45:17,079 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 148 (<unknown>, line 150)
# 2026-02-18 04:45:17,082 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 146 (<unknown>, line 148)
# 2026-02-18 04:45:17,084 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 146 (<unknown>, line 148)
# 2026-02-18 04:45:17,097 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# 2026-02-18 04:45:17,098 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# 2026-02-18 04:45:17,231 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 212 (<unknown>, line 215)
# 2026-02-18 04:45:17,232 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 212 (<unknown>, line 215)
# 2026-02-18 04:45:17,234 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 210 (<unknown>, line 213)
# 2026-02-18 04:45:17,236 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 210 (<unknown>, line 213)
# 2026-02-18 04:45:17,238 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 210 (<unknown>, line 213)
# 2026-02-18 04:45:17,240 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 210 (<unknown>, line 213)
# 2026-02-18 04:45:17,241 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 201 (<unknown>, line 204)
# 2026-02-18 04:45:17,243 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 201 (<unknown>, line 204)
# 2026-02-18 04:45:17,261 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 53 (<unknown>, line 56)
# 2026-02-18 04:45:17,262 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 56 (<unknown>, line 59)
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# 2026-02-18 04:45:17,285 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:17,285 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:17,286 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 37 (<unknown>, line 40)
# 2026-02-18 04:45:17,287 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 37 (<unknown>, line 40)
# 2026-02-18 04:45:17,288 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 37 (<unknown>, line 40)
# 2026-02-18 04:45:17,289 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 37 (<unknown>, line 40)
# 2026-02-18 04:45:17,313 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 220 (<unknown>, line 223)
# 2026-02-18 04:45:17,314 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 222 (<unknown>, line 225)
# parse error
# parse error
# parse error
# parse error
# Processing:  27%|██▋       | 26478/99374 [17:50<02:42, 447.27it/s]2026-02-18 04:45:17,905 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 12 (<unknown>, line 15)
# 2026-02-18 04:45:17,905 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 12 (<unknown>, line 15)
# parse error
# Processing:  27%|██▋       | 26578/99374 [17:50<03:37, 334.88it/s]2026-02-18 04:45:18,182 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 212 (<unknown>, line 215)
# 2026-02-18 04:45:18,183 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 215 (<unknown>, line 218)
# 2026-02-18 04:45:18,184 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 221 (<unknown>, line 224)
# 2026-02-18 04:45:18,185 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 221 (<unknown>, line 224)
# 2026-02-18 04:45:18,318 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# 2026-02-18 04:45:18,318 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# parse error
# parse error
# parse error
# 2026-02-18 04:45:18,942 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 227 (<unknown>, line 230)
# 2026-02-18 04:45:18,944 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 238 (<unknown>, line 241)
# parse error
# 2026-02-18 04:45:19,210 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 31 (<unknown>, line 34)
# 2026-02-18 04:45:19,210 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 31 (<unknown>, line 34)
# 2026-02-18 04:45:19,218 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 30 (<unknown>, line 33)
# 2026-02-18 04:45:19,219 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 30 (<unknown>, line 33)
# Processing:  27%|██▋       | 26653/99374 [17:51<06:05, 198.84it/s]
# parse error
# parse error
# Processing:  27%|██▋       | 26708/99374 [17:52<07:14, 167.10it/s]2026-02-18 04:45:20,049 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 35 (<unknown>, line 43)
# 2026-02-18 04:45:20,049 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 35 (<unknown>, line 43)
# parse error
# Processing:  27%|██▋       | 26806/99374 [17:53<09:09, 131.94it/s]2026-02-18 04:45:21,096 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# 2026-02-18 04:45:21,097 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# Processing:  27%|██▋       | 26847/99374 [17:53<09:10, 131.72it/s]
# parse error
# 2026-02-18 04:45:21,413 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 90 (<unknown>, line 93)
# 2026-02-18 04:45:21,414 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 92 (<unknown>, line 95)
# Processing:  27%|██▋       | 26864/99374 [17:54<10:19, 117.11it/s]2026-02-18 04:45:21,595 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 26 (<unknown>, line 29)
# 2026-02-18 04:45:21,596 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 26 (<unknown>, line 29)
# parse error
# parse error
# Processing:  27%|██▋       | 26954/99374 [17:54<09:21, 128.87it/s]2026-02-18 04:45:22,236 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 45 (<unknown>, line 45)
# 2026-02-18 04:45:22,237 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 45 (<unknown>, line 45)
# 2026-02-18 04:45:22,238 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 44 (<unknown>, line 44)
# 2026-02-18 04:45:22,239 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 45 (<unknown>, line 45)
# Processing:  27%|██▋       | 26968/99374 [17:54<10:15, 117.69it/s]2026-02-18 04:45:22,356 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 146 (<unknown>, line 148)
# 2026-02-18 04:45:22,358 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 146 (<unknown>, line 148)
# 2026-02-18 04:45:22,359 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 144 (<unknown>, line 146)
# 2026-02-18 04:45:22,360 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 146 (<unknown>, line 148)
# 2026-02-18 04:45:22,377 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# 2026-02-18 04:45:22,379 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# 2026-02-18 04:45:22,380 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# 2026-02-18 04:45:22,382 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# 2026-02-18 04:45:22,383 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 136 (<unknown>, line 138)
# 2026-02-18 04:45:22,385 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 136 (<unknown>, line 138)
# 2026-02-18 04:45:22,386 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 137 (<unknown>, line 139)
# 2026-02-18 04:45:22,387 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 137 (<unknown>, line 139)
# 2026-02-18 04:45:22,388 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 137 (<unknown>, line 139)
# 2026-02-18 04:45:22,389 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 137 (<unknown>, line 139)
# 2026-02-18 04:45:22,391 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 138 (<unknown>, line 140)
# 2026-02-18 04:45:22,393 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 138 (<unknown>, line 140)
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# Processing:  27%|██▋       | 26988/99374 [17:55<09:49, 122.73it/s]2026-02-18 04:45:22,523 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 236 (<unknown>, line 239)
# 2026-02-18 04:45:22,524 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 236 (<unknown>, line 239)
# 2026-02-18 04:45:22,527 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 224 (<unknown>, line 227)
# 2026-02-18 04:45:22,529 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 229 (<unknown>, line 232)
# 2026-02-18 04:45:22,531 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 221 (<unknown>, line 224)
# 2026-02-18 04:45:22,532 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 223 (<unknown>, line 226)
# 2026-02-18 04:45:22,604 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 4 (<unknown>, line 7)
# 2026-02-18 04:45:22,605 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 4 (<unknown>, line 7)
# Processing:  27%|██▋       | 27001/99374 [17:55<09:54, 121.70it/s]
# parse error
# parse error
# parse error
# parse error
# 2026-02-18 04:45:22,743 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 203 (<unknown>, line 206)
# 2026-02-18 04:45:22,745 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 203 (<unknown>, line 206)
# Processing:  27%|██▋       | 27025/99374 [17:55<12:33, 96.01it/s]
# parse error
# 2026-02-18 04:45:22,992 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# 2026-02-18 04:45:22,993 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 133 (<unknown>, line 135)
# Processing:  27%|██▋       | 27074/99374 [17:55<06:34, 183.17it/s]2026-02-18 04:45:23,119 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 80 (<unknown>, line 85)
# 2026-02-18 04:45:23,120 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 84 (<unknown>, line 89)
# Processing:  27%|██▋       | 27095/99374 [17:55<07:00, 172.02it/s]
# parse error
# parse error
# Processing:  27%|██▋       | 27202/99374 [17:57<14:43, 81.71it/s] 2026-02-18 04:45:24,767 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 42 (<unknown>, line 45)
# 2026-02-18 04:45:24,768 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 42 (<unknown>, line 45)
# 2026-02-18 04:45:24,769 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:24,771 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# Processing:  27%|██▋       | 27212/99374 [17:57<17:00, 70.69it/s]2026-02-18 04:45:24,805 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 38 (<unknown>, line 41)
# 2026-02-18 04:45:24,806 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 38 (<unknown>, line 41)
# Processing:  27%|██▋       | 27233/99374 [17:57<12:28, 96.37it/s]
# parse error
# parse error
# parse error
# Processing:  27%|██▋       | 27245/99374 [17:57<12:12, 98.45it/s]2026-02-18 04:45:25,024 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 8 (<unknown>, line 11)
# 2026-02-18 04:45:25,025 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 8 (<unknown>, line 11)
# 2026-02-18 04:45:25,033 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# 2026-02-18 04:45:25,038 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 7 (<unknown>, line 10)
# 2026-02-18 04:45:25,068 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 244 (<unknown>, line 244)
# 2026-02-18 04:45:25,069 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 244 (<unknown>, line 244)
# Processing:  27%|██▋       | 27257/99374 [17:57<12:48, 93.85it/s]
# parse error
# parse error
# parse error
# Processing:  27%|██▋       | 27296/99374 [17:58<11:53, 101.04it/s]2026-02-18 04:45:25,576 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# 2026-02-18 04:45:25,577 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# Processing:  27%|██▋       | 27316/99374 [17:58<09:40, 124.19it/s]
# parse error
# Processing:  28%|██▊       | 27343/99374 [17:58<11:48, 101.67it/s]2026-02-18 04:45:25,965 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 17 (<unknown>, line 20)
# 2026-02-18 04:45:25,966 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 17 (<unknown>, line 20)
# 2026-02-18 04:45:25,972 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 26 (<unknown>, line 29)
# 2026-02-18 04:45:25,973 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 26 (<unknown>, line 29)
# 2026-02-18 04:45:25,994 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 290 (<unknown>, line 292)
# 2026-02-18 04:45:25,996 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 290 (<unknown>, line 292)
# 2026-02-18 04:45:25,998 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 284 (<unknown>, line 286)
# 2026-02-18 04:45:26,000 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 284 (<unknown>, line 286)
# Processing:  28%|██▊       | 27362/99374 [17:58<09:51, 121.67it/s]2026-02-18 04:45:26,124 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 23 (<unknown>, line 26)
# 2026-02-18 04:45:26,125 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 26 (<unknown>, line 29)
# parse error
# parse error
# parse error
# parse error
# parse error
# Processing:  28%|██▊       | 27376/99374 [17:58<10:35, 113.33it/s]2026-02-18 04:45:26,291 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# 2026-02-18 04:45:26,292 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# Processing:  28%|██▊       | 27425/99374 [17:58<05:55, 202.62it/s]2026-02-18 04:45:26,313 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# 2026-02-18 04:45:26,313 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# Processing:  28%|██▊       | 27448/99374 [17:59<06:45, 177.25it/s]
# parse error
# parse error
# 2026-02-18 04:45:26,566 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:26,567 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:26,568 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 87 (<unknown>, line 90)
# 2026-02-18 04:45:26,569 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 88 (<unknown>, line 91)
# Processing:  28%|██▊       | 27469/99374 [17:59<07:51, 152.35it/s]
# parse error
# parse error
# Processing:  28%|██▊       | 27506/99374 [17:59<08:00, 149.44it/s]2026-02-18 04:45:26,934 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 272 (<unknown>, line 272)
# 2026-02-18 04:45:26,936 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 272 (<unknown>, line 272)
# 2026-02-18 04:45:26,944 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 260 (<unknown>, line 260)
# 2026-02-18 04:45:26,946 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 260 (<unknown>, line 260)
# 2026-02-18 04:45:26,948 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 283 (<unknown>, line 283)
# 2026-02-18 04:45:26,949 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 283 (<unknown>, line 283)
# 2026-02-18 04:45:26,951 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 204 (<unknown>, line 204)
# 2026-02-18 04:45:26,952 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 204 (<unknown>, line 204)
# 2026-02-18 04:45:26,954 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 221 (<unknown>, line 221)
# 2026-02-18 04:45:26,955 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 221 (<unknown>, line 221)
# 2026-02-18 04:45:26,965 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 192 (<unknown>, line 192)
# 2026-02-18 04:45:26,967 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 187 (<unknown>, line 187)
# 2026-02-18 04:45:26,968 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 207 (<unknown>, line 207)
# 2026-02-18 04:45:26,970 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 204 (<unknown>, line 204)
# 2026-02-18 04:45:26,972 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 192 (<unknown>, line 192)
# 2026-02-18 04:45:26,974 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 192 (<unknown>, line 192)
# 2026-02-18 04:45:26,977 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 183 (<unknown>, line 183)
# 2026-02-18 04:45:26,978 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 192 (<unknown>, line 192)
# 2026-02-18 04:45:26,981 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 199 (<unknown>, line 199)
# 2026-02-18 04:45:26,982 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 207 (<unknown>, line 207)
# 2026-02-18 04:45:26,989 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 184 (<unknown>, line 184)
# 2026-02-18 04:45:26,990 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 184 (<unknown>, line 184)
# Processing:  28%|██▊       | 27543/99374 [17:59<05:57, 200.67it/s]
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# Processing:  28%|██▊       | 27786/99374 [18:01<05:09, 230.93it/s]2026-02-18 04:45:28,817 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 26 (<unknown>, line 28)
# 2026-02-18 04:45:28,818 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 26 (<unknown>, line 28)
# 2026-02-18 04:45:28,838 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 25 (<unknown>, line 28)
# 2026-02-18 04:45:28,839 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 25 (<unknown>, line 28)
# 2026-02-18 04:45:28,913 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# 2026-02-18 04:45:28,913 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 5 (<unknown>, line 8)
# Processing:  28%|██▊       | 27813/99374 [18:01<04:57, 240.37it/s]
# parse error
# parse error
# parse error
# Processing:  28%|██▊       | 27865/99374 [18:01<06:17, 189.50it/s]2026-02-18 04:45:29,273 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 210 (<unknown>, line 213)
# 2026-02-18 04:45:29,274 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 212 (<unknown>, line 215)
# Processing:  28%|██▊       | 27909/99374 [18:02<06:05, 195.58it/s]
# parse error
# Processing:  28%|██▊       | 27949/99374 [18:02<08:55, 133.33it/s]2026-02-18 04:45:29,880 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 272 (<unknown>, line 272)
# 2026-02-18 04:45:29,882 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 272 (<unknown>, line 272)
# Processing:  28%|██▊       | 28001/99374 [18:02<06:26, 184.61it/s]
# parse error
# Processing:  28%|██▊       | 28081/99374 [18:03<13:41, 86.77it/s] 2026-02-18 04:45:31,164 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:31,165 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:31,175 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:31,176 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:31,176 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 32 (<unknown>, line 35)
# 2026-02-18 04:45:31,177 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 32 (<unknown>, line 35)
# Processing:  28%|██▊       | 28100/99374 [18:03<11:16, 105.43it/s]2026-02-18 04:45:31,286 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,287 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,287 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,288 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,289 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 38 (<unknown>, line 41)
# 2026-02-18 04:45:31,290 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 38 (<unknown>, line 41)
# 2026-02-18 04:45:31,291 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,292 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 39 (<unknown>, line 42)
# 2026-02-18 04:45:31,295 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 30 (<unknown>, line 33)
# 2026-02-18 04:45:31,295 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 30 (<unknown>, line 33)
# 2026-02-18 04:45:31,297 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 23 (<unknown>, line 26)
# 2026-02-18 04:45:31,297 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 23 (<unknown>, line 26)
# 2026-02-18 04:45:31,298 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 30 (<unknown>, line 33)
# 2026-02-18 04:45:31,299 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 30 (<unknown>, line 33)
# 2026-02-18 04:45:31,299 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 35 (<unknown>, line 38)
# 2026-02-18 04:45:31,301 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 35 (<unknown>, line 38)
# Processing:  28%|██▊       | 28113/99374 [18:03<11:04, 107.18it/s]2026-02-18 04:45:31,359 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:31,360 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# 2026-02-18 04:45:31,477 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 40 (<unknown>, line 43)
# 2026-02-18 04:45:31,478 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 44 (<unknown>, line 47)
# Processing:  28%|██▊       | 28126/99374 [18:04<11:35, 102.45it/s]2026-02-18 04:45:31,586 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 40 (<unknown>, line 43)
# 2026-02-18 04:45:31,587 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 40 (<unknown>, line 43)
# Processing:  28%|██▊       | 28139/99374 [18:04<11:04, 107.23it/s]2026-02-18 04:45:31,626 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 28 (<unknown>, line 31)
# 2026-02-18 04:45:31,627 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 28 (<unknown>, line 31)
# parse error
# parse error
# parse error
# Processing:  28%|██▊       | 28151/99374 [18:04<11:02, 107.53it/s]2026-02-18 04:45:31,759 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 53 (<unknown>, line 56)
# 2026-02-18 04:45:31,760 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 53 (<unknown>, line 56)
# Processing:  28%|██▊       | 28174/99374 [18:04<11:42, 101.40it/s]
# parse error
# Processing:  28%|██▊       | 28262/99374 [18:05<13:22, 88.66it/s] 2026-02-18 04:45:33,020 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 33 (<unknown>, line 36)
# 2026-02-18 04:45:33,021 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 33 (<unknown>, line 36)
# Processing:  28%|██▊       | 28292/99374 [18:05<09:00, 131.59it/s]2026-02-18 04:45:33,087 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:33,088 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:33,088 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:33,089 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:33,094 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# 2026-02-18 04:45:33,096 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 34 (<unknown>, line 37)
# Processing:  28%|██▊       | 28310/99374 [18:05<08:24, 140.72it/s]2026-02-18 04:45:33,171 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 36)
# parse error
# parse error
# parse error
# parse error
# parse error
# Processing:  29%|██▉       | 28810/99374 [18:07<05:44, 205.11it/s]2026-02-18 04:45:35,272 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 82 (<unknown>, line 84)
# 2026-02-18 04:45:35,272 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 82 (<unknown>, line 84)
# Processing:  29%|██▉       | 28832/99374 [18:08<07:57, 147.86it/s]
# parse error
# Processing:  29%|██▉       | 28892/99374 [18:08<07:26, 157.95it/s]2026-02-18 04:45:35,812 - ERROR - Syntax error while parsing: expected one or more exception types (<unknown>, line 11)
# 2026-02-18 04:45:35,813 - ERROR - Syntax error while parsing: expected one or more exception types (<unknown>, line 12)
# 2026-02-18 04:45:35,817 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# 2026-02-18 04:45:35,818 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# 2026-02-18 04:45:35,819 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# 2026-02-18 04:45:35,820 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# 2026-02-18 04:45:35,823 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# 2026-02-18 04:45:35,824 - ERROR - Syntax error while parsing: invalid syntax (<unknown>, line 32)
# Processing:  29%|██▉       | 28962/99374 [18:08<05:38, 207.93it/s]
# parse error
# parse error
# parse error
# parse error
# Processing:  29%|██▉       | 29077/99374 [18:09<14:12, 82.50it/s] 2026-02-18 04:45:37,255 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 13 (<unknown>, line 16)
# 2026-02-18 04:45:37,256 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 13 (<unknown>, line 16)
# 2026-02-18 04:45:37,272 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 12 (<unknown>, line 15)
# 2026-02-18 04:45:37,273 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 12 (<unknown>, line 15)
# Processing:  29%|██▉       | 29088/99374 [18:10<15:25, 75.98it/s]
# parse error
# parse error
# Processing:  29%|██▉       | 29159/99374 [18:11<15:31, 75.41it/s]2026-02-18 04:45:38,712 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 246 (<unknown>, line 248)
# 2026-02-18 04:45:38,717 - ERROR - Syntax error while parsing: expected an indented block after function definition on line 244 (<unknown>, line 246)
# 2026-02-18 04:45:38,759 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# 2026-02-18 04:45:38,760 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 10 (<unknown>, line 13)
# 2026-02-18 04:45:38,762 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 44 (<unknown>, line 47)
# 2026-02-18 04:45:38,766 - ERROR - Syntax error while parsing: expected an indented block after class definition on line 44 (<unknown>, line 47)
# Processing:  29%|██▉       | 29179/99374 [18:11<14:38, 79.86it/s]
# parse error
# parse error
# parse error
# Processing:  30%|██▉       | 29494/99374 [18:13<02:49, 411.11it/s]<unknown>:2: SyntaxWarning: invalid decimal literal
# <unknown>:2: SyntaxWarning: invalid decimal literal
# Processing:  30%|███       | 30241/99374 [18:13<01:00, 1145.03it/s]<unknown>:13: SyntaxWarning: invalid decimal literal
# <unknown>:13: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# Processing:  35%|███▌      | 35092/99374 [18:20<00:53, 1199.45it/s]<unknown>:18: SyntaxWarning: invalid decimal literal
# <unknown>:18: SyntaxWarning: invalid decimal literal
# Processing:  36%|███▌      | 35721/99374 [18:21<00:52, 1214.55it/s]<unknown>:4: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  40%|████      | 40214/99374 [18:25<00:48, 1230.23it/s]<unknown>:5: SyntaxWarning: invalid decimal literal
# Processing:  41%|████      | 40880/99374 [18:25<00:47, 1220.47it/s]<unknown>:10: SyntaxWarning: invalid decimal literal
# <unknown>:7: SyntaxWarning: invalid decimal literal
# <unknown>:10: SyntaxWarning: invalid decimal literal
# <unknown>:12: SyntaxWarning: invalid decimal literal
# <unknown>:7: SyntaxWarning: invalid decimal literal
# <unknown>:12: SyntaxWarning: invalid decimal literal
# Processing:  43%|████▎     | 42963/99374 [18:27<00:44, 1281.55it/s]<unknown>:3: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  44%|████▎     | 43341/99374 [18:27<00:50, 1114.90it/s]<unknown>:11: SyntaxWarning: invalid decimal literal
# <unknown>:11: SyntaxWarning: invalid decimal literal
# Processing:  45%|████▌     | 45089/99374 [18:29<00:44, 1221.69it/s]<unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# Processing:  47%|████▋     | 46956/99374 [18:30<00:47, 1097.27it/s]<unknown>:13: SyntaxWarning: invalid decimal literal
# Processing:  50%|████▉     | 49512/99374 [18:35<01:03, 790.42it/s] <unknown>:33: SyntaxWarning: invalid decimal literal
# <unknown>:35: SyntaxWarning: invalid decimal literal
# Processing:  51%|█████▏    | 51096/99374 [11:43:37<299:08:31, 22.31s/it]  <unknown>:3: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  52%|█████▏    | 51845/99374 [11:43:38<51:35:34,  3.91s/it] <unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# Processing:  53%|█████▎    | 52279/99374 [11:43:38<20:40:21,  1.58s/it]<unknown>:33: SyntaxWarning: invalid decimal literal
# <unknown>:33: SyntaxWarning: invalid decimal literal
# Processing:  58%|█████▊    | 57557/99374 [11:43:44<00:56, 736.82it/s]  <unknown>:27: SyntaxWarning: invalid decimal literal
# Processing:  58%|█████▊    | 57816/99374 [11:43:44<00:51, 808.49it/s]<unknown>:3: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  60%|█████▉    | 59264/99374 [11:43:46<00:50, 799.35it/s]<unknown>:11: SyntaxWarning: invalid decimal literal
# Processing:  65%|██████▍   | 64316/99374 [11:43:52<00:42, 829.46it/s] <unknown>:16: SyntaxWarning: invalid decimal literal
# <unknown>:16: SyntaxWarning: invalid decimal literal
# Processing:  67%|██████▋   | 66272/99374 [11:43:54<00:40, 807.94it/s]<unknown>:10: SyntaxWarning: invalid decimal literal
# <unknown>:10: SyntaxWarning: invalid decimal literal
# Processing:  71%|███████▏  | 70918/99374 [11:43:59<00:33, 844.95it/s]<unknown>:10: SyntaxWarning: invalid decimal literal
# Processing:  72%|███████▏  | 71273/99374 [11:44:00<00:33, 837.45it/s]<unknown>:42: SyntaxWarning: invalid decimal literal
# <unknown>:39: SyntaxWarning: invalid decimal literal
# Processing:  75%|███████▍  | 74253/99374 [11:44:04<00:30, 834.39it/s]<unknown>:8: SyntaxWarning: invalid decimal literal
# <unknown>:8: SyntaxWarning: invalid decimal literal
# Processing:  75%|███████▍  | 74426/99374 [11:44:05<00:32, 771.51it/s]<unknown>:8: SyntaxWarning: invalid decimal literal
# <unknown>:10: SyntaxWarning: invalid decimal literal
# <unknown>:12: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:16: SyntaxWarning: invalid decimal literal
# <unknown>:18: SyntaxWarning: invalid decimal literal
# <unknown>:20: SyntaxWarning: invalid decimal literal
# <unknown>:8: SyntaxWarning: invalid decimal literal
# <unknown>:10: SyntaxWarning: invalid decimal literal
# <unknown>:12: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:16: SyntaxWarning: invalid decimal literal
# <unknown>:18: SyntaxWarning: invalid decimal literal
# <unknown>:20: SyntaxWarning: invalid decimal literal
# <unknown>:22: SyntaxWarning: invalid decimal literal
# Processing:  75%|███████▌  | 75007/99374 [11:44:05<00:26, 927.13it/s]<unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# Processing:  76%|███████▌  | 75404/99374 [11:44:06<00:24, 972.84it/s]<unknown>:3: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  79%|███████▉  | 78518/99374 [11:44:09<00:26, 795.72it/s]<unknown>:4: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  85%|████████▍ | 84129/99374 [11:44:16<00:16, 928.77it/s]<unknown>:18: SyntaxWarning: invalid decimal literal
# <unknown>:21: SyntaxWarning: invalid decimal literal
# Processing:  85%|████████▍ | 84247/99374 [11:44:16<00:15, 998.92it/s]<unknown>:4: SyntaxWarning: invalid decimal literal
# <unknown>:4: SyntaxWarning: invalid decimal literal
# Processing:  88%|████████▊ | 87384/99374 [11:47:37<00:31, 374.89it/s] <unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# <unknown>:14: SyntaxWarning: invalid decimal literal
# Processing:  91%|█████████▏| 90716/99374 [11:47:41<00:09, 884.31it/s]<unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# Processing:  92%|█████████▏| 91881/99374 [11:47:42<00:08, 935.39it/s]<unknown>:6: SyntaxWarning: invalid decimal literal
# <unknown>:6: SyntaxWarning: invalid decimal literal
# Processing:  96%|█████████▌| 95094/99374 [11:47:45<00:04, 1030.41it/s]<unknown>:3: SyntaxWarning: invalid decimal literal
# Processing:  97%|█████████▋| 96039/99374 [11:47:46<00:03, 1039.18it/s]<unknown>:3: SyntaxWarning: invalid decimal literal
# <unknown>:3: SyntaxWarning: invalid decimal literal
# Processing: 100%|██████████| 99374/99374 [11:47:50<00:00,  2.34it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main("combined_dataset_99k_samples.csv","filtered_first_pass_99k.csv")
#
# Cell In[1], line 213, in main(input_csv, output_csv)
#     209         logger.error(f"Row {idx} failed with exception: {e}")
#     210         continue
# --> 213 logger.info(f"Kept {len(filtered_df)} rows out of {len(df)}")
#     215 # Save
#     216 filtered_df.to_csv(output_csv, index=False)
#
# NameError: name 'filtered_df' is not defined

# %% [markdown]
# lmk.info()
